# %% [markdown]
# ## Using mlxtend on Association Rule Data Mining
#
# Sixian Chen
#
# 11/20/2020
#
# LinkedIn: http://linkedin.com/in/seashane-sixian-chen
#
# Inspired by http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/.
#
# ------
# About The Dataset
# The census dataset provided in a CSV file consists of the attributes age, sex, education, native-country, race, marital-status, workclass, occupation, hours-per-week, income, capital-gain, and capital-loss. The CSV file census.csv contains exactly 30162 rows and each row contains exactly 12 comma separated values in the form attribute=value.
#
# ----

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
pd.set_option('display.max_colwidth',0)

census_data = pd.read_csv("census.csv", header = None)
num_records = len(census_data)

records = []
for i in range(0, num_records):
    records.append([str(census_data.values[i,j]) for j in range(0, 12)])

# %%
print("This dataset has", len(records), "entries. \n")
# Out:
# This dataset has 30162 entries.

# %%
dfRecords = pd.DataFrame(records)

print("Let's preview the dataset.")
dfRecords.head(5)
# Out:
# Let's preview the dataset.
#                  0           1                    2  \
# 0  age=Middle-aged  sex=Male    education=Bachelors
# 1  age=Senior       sex=Male    education=Bachelors
# 2  age=Middle-aged  sex=Male    education=HS-grad
# 3  age=Senior       sex=Male    education=11th
# 4  age=Middle-aged  sex=Female  education=Bachelors
#
#                               3           4  \
# 0  native-country=United-States  race=White
# 1  native-country=United-States  race=White
# 2  native-country=United-States  race=White
# 3  native-country=United-States  race=Black
# 4  native-country=Cuba           race=Black
#
#                                    5                           6  \
# 0  marital-status=Never-married       workclass=State-gov
# 1  marital-status=Married-civ-spouse  workclass=Self-emp-not-inc
# 2  marital-status=Divorced            workclass=Private
# 3  marital-status=Married-civ-spouse  workclass=Private
# 4  marital-status=Married-civ-spouse  workclass=Private
#
#                               7                         8             9  \
# 0  occupation=Adm-clerical       hours-per-week=Full-time  income=Small
# 1  occupation=Exec-managerial    hours-per-week=Part-time  income=Small
# 2  occupation=Handlers-cleaners  hours-per-week=Full-time  income=Small
# 3  occupation=Handlers-cleaners  hours-per-week=Full-time  income=Small
# 4  occupation=Prof-specialty     hours-per-week=Full-time  income=Small
#
#                   10                 11
# 0  capital-gain=Low   capital-loss=None
# 1  capital-gain=None  capital-loss=None
# 2  capital-gain=None  capital-loss=None
# 3  capital-gain=None  capital-loss=None
# 4  capital-gain=None  capital-loss=None

# %%
te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_comb = fpgrowth(df, min_support=0.3, use_colnames=True)

from mlxtend.frequent_patterns import association_rules

aRule= association_rules(frequent_comb, metric="confidence") 
aRule.sort_values('confidence', ascending = False, inplace = True) # Sort the values by confidence
aRule['length'] = aRule['antecedents'].apply(lambda x: len(x))+1


print("The following dataframe shows the statistics of the association rules sorting by confidence.")
aRule.head(7)
# Out:
# The following dataframe shows the statistics of the association rules sorting by confidence.
#                                                                                                       antecedents  \
# 440  (income=Small, workclass=Private, hours-per-week=Full-time)
# 456  (income=Small, workclass=Private, native-country=United-States, hours-per-week=Full-time)
# 451  (income=Small, workclass=Private, capital-gain=None, hours-per-week=Full-time)
# 768  (income=Small, workclass=Private)
# 465  (native-country=United-States, workclass=Private, hours-per-week=Full-time, income=Small, capital-gain=None)
# 582  (marital-status=Never-married)
# 314  (income=Small, hours-per-week=Full-time)
#
#              consequents  antecedent support  consequent support   support  \
# 440  (capital-loss=None)  0.370101            0.952689            0.360221
# 456  (capital-loss=None)  0.326702            0.952689            0.317651
# 451  (capital-loss=None)  0.356044            0.952689            0.346164
# 768  (capital-loss=None)  0.577216            0.952689            0.560772
# 465  (capital-loss=None)  0.314004            0.952689            0.304953
# 582  (capital-loss=None)  0.322459            0.952689            0.313010
# 314  (capital-loss=None)  0.469001            0.952689            0.455109
#
#      confidence      lift  leverage  conviction  length
# 440  0.973305    1.021640  0.007630  1.772264    4
# 456  0.972296    1.020580  0.006406  1.707709    5
# 451  0.972251    1.020533  0.006965  1.704949    5
# 768  0.971511    1.019757  0.010864  1.660661    3
# 465  0.971175    1.019404  0.005805  1.641334    6
# 582  0.970697    1.018903  0.005807  1.614556    2
# 314  0.970380    1.018570  0.008297  1.597289    3

# %%
aRule["antecedents"] = aRule["antecedents"].astype(str)
aRule['antecedents'] = aRule['antecedents'].map(lambda x: x.lstrip('frozenset').rstrip('('')'))
aRule['antecedents'] = aRule['antecedents'].map(lambda x: x.lstrip('()').rstrip('frozenset'))

aRule["consequents"] = aRule["consequents"].astype(str)
aRule['consequents'] = aRule['consequents'].map(lambda x: x.lstrip('frozenset').rstrip('('')'))
aRule['consequents'] = aRule['consequents'].map(lambda x: x.lstrip('()').rstrip('frozenset'))

aRule['association'] = aRule['antecedents']+"=>"+aRule['consequents']

aRuleAsso = aRule[['association','confidence','support','lift','length']]

print("The top 10 association rules that are most likely to happen:")
aRuleAsso.head(10)
# Out:
# The top 10 association rules that are most likely to happen:
#                                                                                                                                        association  \
# 440  {'income=Small', 'workclass=Private', 'hours-per-week=Full-time'}=>{'capital-loss=None'}
# 456  {'income=Small', 'workclass=Private', 'native-country=United-States', 'hours-per-week=Full-time'}=>{'capital-loss=None'}
# 451  {'income=Small', 'workclass=Private', 'capital-gain=None', 'hours-per-week=Full-time'}=>{'capital-loss=None'}
# 768  {'income=Small', 'workclass=Private'}=>{'capital-loss=None'}
# 465  {'native-country=United-States', 'workclass=Private', 'hours-per-week=Full-time', 'income=Small', 'capital-gain=None'}=>{'capital-loss=None'}
# 582  {'marital-status=Never-married'}=>{'capital-loss=None'}
# 314  {'income=Small', 'hours-per-week=Full-time'}=>{'capital-loss=None'}
# 777  {'income=Small', 'workclass=Private', 'native-country=United-States'}=>{'capital-loss=None'}
# 773  {'income=Small', 'workclass=Private', 'capital-gain=None'}=>{'capital-loss=None'}
# 792  {'income=Small', 'workclass=Private', 'race=White'}=>{'capital-loss=None'}
#
#      confidence   support      lift  length
# 440  0.973305    0.360221  1.021640  4
# 456  0.972296    0.317651  1.020580  5
# 451  0.972251    0.346164  1.020533  5
# 768  0.971511    0.560772  1.019757  3
# 465  0.971175    0.304953  1.019404  6
# 582  0.970697    0.313010  1.018903  2
# 314  0.970380    0.455109  1.018570  3
# 777  0.970373    0.501691  1.018563  4
# 773  0.970346    0.538094  1.018534  4
# 792  0.970211    0.471885  1.018393  4

# %%
aRuleAsso.head(1)['association'].to_list
print("The association rule",aRuleAsso.head(1)["association"].values, "has the most likelyhood to happen.\n")
# Out:
# The association rule ["{'income=Small', 'workclass=Private', 'hours-per-week=Full-time'}=>{'capital-loss=None'}"] has the most likelyhood to happen.

# %% [markdown]
# -----
# ### What are the associated antecedents would lead to a high capital gain?
# Let's focus on the records that only has high capital gain

# %%
HighCapGain = dfRecords[dfRecords[10]=='capital-gain=High']
print("We have",len(HighCapGain),"records have high capital gain.\n")
# Out:
# We have 1090 records have high capital gain.

# %%
HighCapGain = HighCapGain.values.tolist()
HighCapGain

te = TransactionEncoder()
te_ary = te.fit(HighCapGain).transform(HighCapGain)
df = pd.DataFrame(te_ary, columns=te.columns_)

frequent_comb = fpgrowth(df, min_support=0.3, use_colnames=True)

from mlxtend.frequent_patterns import association_rules

aRule= association_rules(frequent_comb, metric="confidence") 
aRule.sort_values('confidence', ascending = False, inplace = True) # Sort the values by confidence
aRule['length'] = aRule['antecedents'].apply(lambda x: len(x))+1

print("The following dataframe shows the statistics of the association rules sorting by confidence.")

aRule.head(10)
# Out:
# The following dataframe shows the statistics of the association rules sorting by confidence.
#                                                                                          antecedents  \
# 0     (capital-gain=High)
# 2511  (income=Large, native-country=United-States, sex=Male, hours-per-week=Over-time)
# 2315  (workclass=Private, native-country=United-States, hours-per-week=Over-time)
# 2313  (capital-gain=High, workclass=Private, native-country=United-States, hours-per-week=Over-time)
# 2312  (workclass=Private, native-country=United-States, capital-loss=None, hours-per-week=Over-time)
# 2309  (workclass=Private, native-country=United-States, hours-per-week=Over-time)
# 2307  (workclass=Private, native-country=United-States, hours-per-week=Over-time)
# 2304  (workclass=Private, hours-per-week=Over-time, income=Large)
# 2301  (capital-gain=High, workclass=Private, hours-per-week=Over-time, income=Large)
# 2300  (income=Large, workclass=Private, hours-per-week=Over-time, capital-loss=None)
#
#                                  consequents  antecedent support  \
# 0     (capital-loss=None)                     1.000000
# 2511  (capital-loss=None)                     0.397248
# 2315  (capital-gain=High, capital-loss=None)  0.300000
# 2313  (capital-loss=None)                     0.300000
# 2312  (capital-gain=High)                     0.300000
# 2309  (capital-loss=None)                     0.300000
# 2307  (capital-gain=High)                     0.300000
# 2304  (capital-gain=High, capital-loss=None)  0.317431
# 2301  (capital-loss=None)                     0.317431
# 2300  (capital-gain=High)                     0.317431
#
#       consequent support   support  confidence  lift  leverage  conviction  \
# 0     1.0                 1.000000  1.0         1.0   0.0       inf
# 2511  1.0                 0.397248  1.0         1.0   0.0       inf
# 2315  1.0                 0.300000  1.0         1.0   0.0       inf
# 2313  1.0                 0.300000  1.0         1.0   0.0       inf
# 2312  1.0                 0.300000  1.0         1.0   0.0       inf
# 2309  1.0                 0.300000  1.0         1.0   0.0       inf
# 2307  1.0                 0.300000  1.0         1.0   0.0       inf
# 2304  1.0                 0.317431  1.0         1.0   0.0       inf
# 2301  1.0                 0.317431  1.0         1.0   0.0       inf
# 2300  1.0                 0.317431  1.0         1.0   0.0       inf
#
#       length
# 0     2
# 2511  5
# 2315  4
# 2313  5
# 2312  5
# 2309  4
# 2307  4
# 2304  4
# 2301  5
# 2300  5

# %%
aRule = aRule.reset_index()
aRule["antecedents"] = aRule["antecedents"].astype(str)
aRule['antecedents'] = aRule['antecedents'].map(lambda x: x.lstrip('frozenset').rstrip('('')'))
aRule['antecedents'] = aRule['antecedents'].map(lambda x: x.lstrip('()').rstrip('frozenset'))

aRule["consequents"] = aRule["consequents"].astype(str)
aRule['consequents'] = aRule['consequents'].map(lambda x: x.lstrip('frozenset').rstrip('('')'))
aRule['consequents'] = aRule['consequents'].map(lambda x: x.lstrip('()').rstrip('frozenset'))

aRule['association'] = aRule['antecedents']+"=>"+aRule['consequents']

aRuleAsso = aRule[['association','confidence','support','lift','length']]

print("The top 10 association rules that are most likely to happen:")
aRuleAsso.head(10)
# Out:
# The top 10 association rules that are most likely to happen:
#                                                                                                                      association  \
# 0  {'capital-gain=High'}=>{'capital-loss=None'}
# 1  {'income=Large', 'native-country=United-States', 'sex=Male', 'hours-per-week=Over-time'}=>{'capital-loss=None'}
# 2  {'workclass=Private', 'native-country=United-States', 'hours-per-week=Over-time'}=>{'capital-gain=High', 'capital-loss=None'}
# 3  {'capital-gain=High', 'workclass=Private', 'native-country=United-States', 'hours-per-week=Over-time'}=>{'capital-loss=None'}
# 4  {'workclass=Private', 'native-country=United-States', 'capital-loss=None', 'hours-per-week=Over-time'}=>{'capital-gain=High'}
# 5  {'workclass=Private', 'native-country=United-States', 'hours-per-week=Over-time'}=>{'capital-loss=None'}
# 6  {'workclass=Private', 'native-country=United-States', 'hours-per-week=Over-time'}=>{'capital-gain=High'}
# 7  {'workclass=Private', 'hours-per-week=Over-time', 'income=Large'}=>{'capital-gain=High', 'capital-loss=None'}
# 8  {'capital-gain=High', 'workclass=Private', 'hours-per-week=Over-time', 'income=Large'}=>{'capital-loss=None'}
# 9  {'income=Large', 'workclass=Private', 'hours-per-week=Over-time', 'capital-loss=None'}=>{'capital-gain=High'}
#
#    confidence   support  lift  length
# 0  1.0         1.000000  1.0   2
# 1  1.0         0.397248  1.0   5
# 2  1.0         0.300000  1.0   4
# 3  1.0         0.300000  1.0   5
# 4  1.0         0.300000  1.0   5
# 5  1.0         0.300000  1.0   4
# 6  1.0         0.300000  1.0   4
# 7  1.0         0.317431  1.0   4
# 8  1.0         0.317431  1.0   5
# 9  1.0         0.317431  1.0   5

# %%
value = int(input("Enter the total length of the association rule: "))
# Out:
# Enter the total length of the association rule: 3

# %%
aRule = aRule[aRule['length']==value]
aRule = aRule[aRule['consequents']=="{'capital-gain=High'}"]
aRule = aRule.sort_values(by=['support'],ascending=False)
#aRule

# %%
aRule['association'] = aRule['antecedents']+"=>"+aRule['consequents']
aRuleAsso = aRule[['association','confidence','support','lift','length']]
print("The top 10 association rules that are most likely to happen:")
aRuleAsso.head(10)
# Out:
# The top 10 association rules that are most likely to happen:
#                                                                       association  \
# 681  {'income=Large', 'capital-loss=None'}=>{'capital-gain=High'}
# 479  {'native-country=United-States', 'capital-loss=None'}=>{'capital-gain=High'}
# 511  {'income=Large', 'native-country=United-States'}=>{'capital-gain=High'}
# 641  {'race=White', 'capital-loss=None'}=>{'capital-gain=High'}
# 572  {'income=Large', 'race=White'}=>{'capital-gain=High'}
# 591  {'race=White', 'native-country=United-States'}=>{'capital-gain=High'}
# 725  {'capital-loss=None', 'sex=Male'}=>{'capital-gain=High'}
# 717  {'income=Large', 'sex=Male'}=>{'capital-gain=High'}
# 711  {'native-country=United-States', 'sex=Male'}=>{'capital-gain=High'}
# 855  {'race=White', 'sex=Male'}=>{'capital-gain=High'}
#
#      confidence   support  lift  length
# 681  1.0         0.983486  1.0   3
# 479  1.0         0.937615  1.0   3
# 511  1.0         0.922018  1.0   3
# 641  1.0         0.900000  1.0   3
# 572  1.0         0.884404  1.0   3
# 591  1.0         0.863303  1.0   3
# 725  1.0         0.814679  1.0   3
# 717  1.0         0.804587  1.0   3
# 711  1.0         0.761468  1.0   3
# 855  1.0         0.741284  1.0   3

# %%
print("\nFrom the association rule table above, we can see that, for people who has a high capital gain, he or she usually has the following top 5 (sets of) characteristics sorting by the support of the rules when the length of association is",value,".\n")
print(*aRule['antecedents'][0:5].values,sep='\n')
# Out:
# From the association rule table above, we can see that, for people who has a high capital gain, he or she usually has the following top 5 (sets of) characteristics sorting by the support of the rules when the length of association is 3 .
#
# {'income=Large', 'capital-loss=None'}
# {'native-country=United-States', 'capital-loss=None'}
# {'income=Large', 'native-country=United-States'}
# {'race=White', 'capital-loss=None'}
# {'income=Large', 'race=White'}
